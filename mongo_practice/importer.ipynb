# %%
from mango import AnimalShelter
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 from mango import AnimalShelter
#
# File ~/Documents/College/SNHU/mongo_practice/mango.py:3, in <module>
#       1 {
#       2  "cells": [
# ----> 3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "from pymongo import MongoClient\n",
#      10     "# from bson.objectid import ObjectId\n",
#      11     "\n",
#      12     "class AnimalShelter(object):\n",
#      13     "    \"\"\" CRUD operations for Animal collection in MongoDB \"\"\"\n",
#      14     "\n",
#      15     "    def __init__(self):\n",
#      16     "        # Initializing the MongoClient. This helps to \n",
#      17     "        # access the MongoDB databases and collections. \n",
# ...
